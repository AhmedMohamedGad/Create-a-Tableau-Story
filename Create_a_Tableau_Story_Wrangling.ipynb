# %% [markdown]
# # Airline On-Time Statistics and Delay Causes - Data Wrangling
#
# I'm trying to describes the wrangling of the dataset required for the visualization using Tableau within Udacity's Data Analyst Project : "Create a Tableau Story".
#
# As a dataset, we have chosen the Flight Delay Dataset, which can be found [here](https://www.transtats.bts.gov/OT_Delay/OT_DelayCause1.asp?pn=1) (note: the zip file is downloaded manually since a period of time has to be selected.). The source is the Bureau of Transportation Statistics (BTS) Period limit from June 2003 to Septemper 2018.
#
# In further analysis and visualization, we want to take a look at the data of the recent 8 years to explore temporal trends. Thus, the period of the recent available data has been choosen, in our case from Aug, 2010 to Aug, 2018. Additional data from this site are also required to get more geographical data.
#
# ## Gathering
#
# We gather Flights data from the [website](https://www.transtats.bts.gov/OT_Delay/OT_DelayCause1.asp?pn=1). Therefor, we download the data manually. The archive is then unzipped and converted into a Pandas dataframe programmatically, so we can assess the data in the next step of the data wrangling process.

# %%
# Import required modules to the python notebook
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import zipfile
import datetime

# %matplotlib inline

# %%
# Unzip the PISA archive
zipped_data = zipfile.ZipFile('82404974_92018_162_airline_delay_causes.zip', 'r')
zipped_data.extractall()
zipped_data.close()

# %%
# Read CSV file
df_flight = pd.read_csv('82404974_92018_162_airline_delay_causes.zip')
df_flight.head()
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2003       6      AA  American Airlines Inc.     ABQ
# 1  2003       6      AA  American Airlines Inc.     ANC
# 2  2003       6      AA  American Airlines Inc.     ATL
# 3  2003       6      AA  American Airlines Inc.     AUS
# 4  2003       6      AA  American Airlines Inc.     BDL
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Albuquerque, NM: Albuquerque International Sun...        307.0       56.0
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...         90.0       27.0
# 2  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        752.0      186.0
# 3       Austin, TX: Austin - Bergstrom International        842.0      174.0
# 4                Hartford, CT: Bradley International        383.0       55.0
#
#    carrier_ct   weather_ct     ...       late_aircraft_ct  arr_cancelled  \
# 0       14.68        10.79     ...                   9.96            1.0
# 1        7.09         2.00     ...                   7.16            0.0
# 2       33.99        27.82     ...                  17.53            5.0
# 3       60.24        20.54     ...                  40.75            9.0
# 4       14.90         8.91     ...                  16.61            0.0
#
#    arr_diverted   arr_delay   carrier_delay  weather_delay  nas_delay  \
# 0           1.0      2530.0           510.0          621.0      676.0
# 1           0.0      1390.0           271.0           83.0      581.0
# 2           0.0      8314.0          1367.0         1722.0     3817.0
# 3           1.0      8344.0          3040.0         1032.0     1835.0
# 4           0.0      3137.0           815.0          574.0      555.0
#
#    security_delay  late_aircraft_delay  Unnamed: 21
# 0            25.0                698.0          NaN
# 1             0.0                455.0          NaN
# 2           139.0               1269.0          NaN
# 3           115.0               2322.0          NaN
# 4             0.0               1193.0          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Assessing
#
# We look at the dataset in detail to identify structural or content-related issues that affect the data tidiness respectively the data quality.

# %%
# View summary of dataset using info()-function
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247718 entries, 0 to 247717
# Data columns (total 22 columns):
# year                   247718 non-null int64
#  month                 247718 non-null int64
# carrier                247718 non-null object
# carrier_name           247718 non-null object
# airport                247718 non-null object
# airport_name           247718 non-null object
# arr_flights            247368 non-null float64
# arr_del15              247317 non-null float64
# carrier_ct             247368 non-null float64
#  weather_ct            247368 non-null float64
# nas_ct                 247368 non-null float64
# security_ct            247368 non-null float64
# late_aircraft_ct       247368 non-null float64
# arr_cancelled          247368 non-null float64
# arr_diverted           247368 non-null float64
#  arr_delay             247368 non-null float64
#  carrier_delay         247368 non-null float64
# weather_delay          247368 non-null float64
# nas_delay              247368 non-null float64
# security_delay         247368 non-null float64
# late_aircraft_delay    247368 non-null float64
# Unnamed: 21            0 non-null float64
# dtypes: float64(16), int64(2), object(4)
# memory usage: 41.6+ MB

# %%
# Check for NaN values in the "arr_del15" column (variable describes the amount of delayed flights)
df_flight[df_flight["arr_del15"].isnull()]
# Out:
#         year   month carrier                 carrier_name airport  \
# 499     2003       6      EV  Atlantic Southeast Airlines     ORF
# 513     2003       6      EV  Atlantic Southeast Airlines     SWF
# 587     2003       6      HP   America West Airlines Inc.     LGB
# 4107    2003       9      DL         Delta Air Lines Inc.     JAC
# 4761    2003       9      RU     ExpressJet Airlines Inc.     TPA
# 4767    2003       9      TZ       ATA Airlines d/b/a ATA     ABQ
# 10568   2004       2      EV  Atlantic Southeast Airlines     ABE
# 10577   2004       2      EV  Atlantic Southeast Airlines     BNA
# 11333   2004       2      TZ       ATA Airlines d/b/a ATA     TPA
# 11954   2004       3      EV  Atlantic Southeast Airlines     BNA
# 11960   2004       3      EV  Atlantic Southeast Airlines     CAK
# 12687   2004       3      TZ       ATA Airlines d/b/a ATA     BWI
# 13377   2004       4      EV  Atlantic Southeast Airlines     LAX
# 15042   2004       5      NW      Northwest Airlines Inc.     GRB
# 15060   2004       5      NW      Northwest Airlines Inc.     LSE
# 15110   2004       5      NW      Northwest Airlines Inc.     TVC
# 17914   2004       7      OH                  Comair Inc.     AZO
# 20641   2004       9      NW      Northwest Airlines Inc.     HLN
# 21476   2004      10      CO   Continental Air Lines Inc.     LBB
# 22968   2004      11      DH             Independence Air     SGF
# 24545   2004      12      EV  Atlantic Southeast Airlines     RSW
# 24978   2004      12      OH                  Comair Inc.     PVD
# 28825   2005       3      HP   America West Airlines Inc.     BOI
# 31283   2005       5      CO   Continental Air Lines Inc.     PSP
# 33484   2005       6      OO        SkyWest Airlines Inc.     ABI
# 35010   2005       7      OO        SkyWest Airlines Inc.     SJT
# 35023   2005       7      OO        SkyWest Airlines Inc.     VCT
# 35436   2005       8      AA       American Airlines Inc.     SHV
# 38988   2005      10      NW      Northwest Airlines Inc.     BTV
# 39139   2005      10      OH                  Comair Inc.     ISP
# ...      ...     ...     ...                          ...     ...
# 218892  2016      11      OO        SkyWest Airlines Inc.     ENV
# 219909  2016      12      OO        SkyWest Airlines Inc.     PNS
# 220027  2016      12      VX               Virgin America     ONT
# 220635  2017       1      EV     ExpressJet Airlines Inc.     TKI
# 223418  2017       4      DL         Delta Air Lines Inc.     BMI
# 224463  2017       5      DL         Delta Air Lines Inc.     BIS
# 225171  2017       5      VX               Virgin America     SLC
# 225712  2017       6      EV     ExpressJet Airlines Inc.     GTR
# 226433  2017       7      EV     ExpressJet Airlines Inc.     GUC
# 228764  2017       9      DL         Delta Air Lines Inc.     JNU
# 228845  2017       9      EV     ExpressJet Airlines Inc.     AUS
# 228938  2017       9      EV     ExpressJet Airlines Inc.     MSY
# 229279  2017       9      OO        SkyWest Airlines Inc.     SIT
# 229328  2017       9      UA        United Air Lines Inc.     EGE
# 229890  2017      10      EV     ExpressJet Airlines Inc.     ALB
# 230147  2017      10      EV     ExpressJet Airlines Inc.     JFK
# 231322  2017      11      OO        SkyWest Airlines Inc.     PWM
# 232219  2017      12      EV     ExpressJet Airlines Inc.     ABI
# 234061  2018       1      EV     ExpressJet Airlines Inc.     MDT
# 234309  2018       1      MQ                    Envoy Air     BDL
# 235965  2018       3      9E            Endeavor Air Inc.     CAK
# 235992  2018       3      9E            Endeavor Air Inc.     GRB
# 236005  2018       3      9E            Endeavor Air Inc.     LNK
# 238028  2018       4      DL         Delta Air Lines Inc.     MTJ
# 238181  2018       4      EV     ExpressJet Airlines Inc.     RSW
# 240404  2018       5      OO        SkyWest Airlines Inc.     GSO
# 243314  2018       7      G4                Allegiant Air     BHM
# 244030  2018       7      UA        United Air Lines Inc.     SBA
# 245484  2018       8      EV     ExpressJet Airlines Inc.     PIA
# 246473  2018       9      OO        SkyWest Airlines Inc.     ABY
#
#                                              airport_name  arr_flights  \
# 499                    Norfolk, VA: Norfolk International          NaN
# 513      Newburgh/Poughkeepsie, NY: Stewart International          NaN
# 587                    Long Beach, CA: Long Beach Airport          NaN
# 4107                            Jackson, WY: Jackson Hole          NaN
# 4761                       Tampa, FL: Tampa International          NaN
# 4767    Albuquerque, NM: Albuquerque International Sun...          NaN
# 10568   Allentown/Bethlehem/Easton, PA: Lehigh Valley ...          NaN
# 10577              Nashville, TN: Nashville International          NaN
# 11333                      Tampa, FL: Tampa International          NaN
# 11954              Nashville, TN: Nashville International          NaN
# 11960                    Akron, OH: Akron-Canton Regional          NaN
# 12687   Baltimore, MD: Baltimore/Washington Internatio...          NaN
# 13377          Los Angeles, CA: Los Angeles International          NaN
# 15042   Green Bay, WI: Green Bay Austin Straubel Inter...          NaN
# 15060                   La Crosse, WI: La Crosse Regional          NaN
# 15110                   Traverse City, MI: Cherry Capital          NaN
# 17914   Kalamazoo, MI: Kalamazoo/Battle Creek Internat...          NaN
# 20641                         Helena, MT: Helena Regional          NaN
# 21476    Lubbock, TX: Lubbock Preston Smith International          NaN
# 22968       Springfield, MO: Springfield-Branson National          NaN
# 24545     Fort Myers, FL: Southwest Florida International          NaN
# 24978        Providence, RI: Theodore Francis Green State          NaN
# 28825                       Boise, ID: Boise Air Terminal          NaN
# 31283        Palm Springs, CA: Palm Springs International          NaN
# 33484                       Abilene, TX: Abilene Regional          NaN
# 35010    San Angelo, TX: San Angelo Regional/Mathis Field          NaN
# 35023                     Victoria, TX: Victoria Regional          NaN
# 35436                 Shreveport, LA: Shreveport Regional          NaN
# 38988            Burlington, VT: Burlington International          NaN
# 39139                    Islip, NY: Long Island MacArthur          NaN
# ...                                                   ...          ...
# 218892                     Wendover, UT: Wendover Airport          NaN
# 219909             Pensacola, FL: Pensacola International          1.0
# 220027                 Ontario, CA: Ontario International          NaN
# 220635                         Tokeen, AK: Tokeen Airport          NaN
# 223418  Bloomington/Normal, IL: Central Illinois Regional          NaN
# 224463            Bismarck/Mandan, ND: Bismarck Municipal          NaN
# 225171   Salt Lake City, UT: Salt Lake City International          1.0
# 225712             Columbus, MS: Golden Triangle Regional          NaN
# 226433      Gunnison, CO: Gunnison-Crested Butte Regional          NaN
# 228764                   Juneau, AK: Juneau International          NaN
# 228845       Austin, TX: Austin - Bergstrom International          1.0
# 228938  New Orleans, LA: Louis Armstrong New Orleans I...          2.0
# 229279                   Sitka, AK: Sitka Rocky Gutierrez          NaN
# 229328                   Eagle, CO: Eagle County Regional          1.0
# 229890                   Albany, NY: Albany International          NaN
# 230147        New York, NY: John F. Kennedy International          1.0
# 231322       Portland, ME: Portland International Jetport          NaN
# 232219                      Abilene, TX: Abilene Regional          NaN
# 234061           Harrisburg, PA: Harrisburg International          NaN
# 234309                Hartford, CT: Bradley International          NaN
# 235965                   Akron, OH: Akron-Canton Regional          NaN
# 235992  Green Bay, WI: Green Bay Austin Straubel Inter...          NaN
# 236005                       Lincoln, NE: Lincoln Airport          NaN
# 238028              Montrose/Delta, CO: Montrose Regional          NaN
# 238181    Fort Myers, FL: Southwest Florida International          1.0
# 240404  Greensboro/High Point, NC: Piedmont Triad Inte...          NaN
# 243314  Birmingham, AL: Birmingham-Shuttlesworth Inter...          NaN
# 244030         Santa Barbara, CA: Santa Barbara Municipal          1.0
# 245484  Peoria, IL: General Downing - Peoria Internati...          1.0
# 246473             Albany, GA: Southwest Georgia Regional          NaN
#
#         arr_del15  carrier_ct   weather_ct     ...       late_aircraft_ct  \
# 499           NaN         NaN          NaN     ...                    NaN
# 513           NaN         NaN          NaN     ...                    NaN
# 587           NaN         NaN          NaN     ...                    NaN
# 4107          NaN         NaN          NaN     ...                    NaN
# 4761          NaN         NaN          NaN     ...                    NaN
# 4767          NaN         NaN          NaN     ...                    NaN
# 10568         NaN         NaN          NaN     ...                    NaN
# 10577         NaN         NaN          NaN     ...                    NaN
# 11333         NaN         NaN          NaN     ...                    NaN
# 11954         NaN         NaN          NaN     ...                    NaN
# 11960         NaN         NaN          NaN     ...                    NaN
# 12687         NaN         NaN          NaN     ...                    NaN
# 13377         NaN         NaN          NaN     ...                    NaN
# 15042         NaN         NaN          NaN     ...                    NaN
# 15060         NaN         NaN          NaN     ...                    NaN
# 15110         NaN         NaN          NaN     ...                    NaN
# 17914         NaN         NaN          NaN     ...                    NaN
# 20641         NaN         NaN          NaN     ...                    NaN
# 21476         NaN         NaN          NaN     ...                    NaN
# 22968         NaN         NaN          NaN     ...                    NaN
# 24545         NaN         NaN          NaN     ...                    NaN
# 24978         NaN         NaN          NaN     ...                    NaN
# 28825         NaN         NaN          NaN     ...                    NaN
# 31283         NaN         NaN          NaN     ...                    NaN
# 33484         NaN         NaN          NaN     ...                    NaN
# 35010         NaN         NaN          NaN     ...                    NaN
# 35023         NaN         NaN          NaN     ...                    NaN
# 35436         NaN         NaN          NaN     ...                    NaN
# 38988         NaN         NaN          NaN     ...                    NaN
# 39139         NaN         NaN          NaN     ...                    NaN
# ...           ...         ...          ...     ...                    ...
# 218892        NaN         NaN          NaN     ...                    NaN
# 219909        NaN         0.0          0.0     ...                    0.0
# 220027        NaN         NaN          NaN     ...                    NaN
# 220635        NaN         NaN          NaN     ...                    NaN
# 223418        NaN         NaN          NaN     ...                    NaN
# 224463        NaN         NaN          NaN     ...                    NaN
# 225171        NaN         0.0          0.0     ...                    0.0
# 225712        NaN         NaN          NaN     ...                    NaN
# 226433        NaN         NaN          NaN     ...                    NaN
# 228764        NaN         NaN          NaN     ...                    NaN
# 228845        NaN         0.0          0.0     ...                    0.0
# 228938        NaN         0.0          0.0     ...                    0.0
# 229279        NaN         NaN          NaN     ...                    NaN
# 229328        NaN         0.0          0.0     ...                    0.0
# 229890        NaN         NaN          NaN     ...                    NaN
# 230147        NaN         0.0          0.0     ...                    0.0
# 231322        NaN         NaN          NaN     ...                    NaN
# 232219        NaN         NaN          NaN     ...                    NaN
# 234061        NaN         NaN          NaN     ...                    NaN
# 234309        NaN         NaN          NaN     ...                    NaN
# 235965        NaN         NaN          NaN     ...                    NaN
# 235992        NaN         NaN          NaN     ...                    NaN
# 236005        NaN         NaN          NaN     ...                    NaN
# 238028        NaN         NaN          NaN     ...                    NaN
# 238181        NaN         0.0          0.0     ...                    0.0
# 240404        NaN         NaN          NaN     ...                    NaN
# 243314        NaN         NaN          NaN     ...                    NaN
# 244030        NaN         0.0          0.0     ...                    0.0
# 245484        NaN         0.0          0.0     ...                    0.0
# 246473        NaN         NaN          NaN     ...                    NaN
#
#         arr_cancelled  arr_diverted   arr_delay   carrier_delay  \
# 499               NaN           NaN         NaN             NaN
# 513               NaN           NaN         NaN             NaN
# 587               NaN           NaN         NaN             NaN
# 4107              NaN           NaN         NaN             NaN
# 4761              NaN           NaN         NaN             NaN
# 4767              NaN           NaN         NaN             NaN
# 10568             NaN           NaN         NaN             NaN
# 10577             NaN           NaN         NaN             NaN
# 11333             NaN           NaN         NaN             NaN
# 11954             NaN           NaN         NaN             NaN
# 11960             NaN           NaN         NaN             NaN
# 12687             NaN           NaN         NaN             NaN
# 13377             NaN           NaN         NaN             NaN
# 15042             NaN           NaN         NaN             NaN
# 15060             NaN           NaN         NaN             NaN
# 15110             NaN           NaN         NaN             NaN
# 17914             NaN           NaN         NaN             NaN
# 20641             NaN           NaN         NaN             NaN
# 21476             NaN           NaN         NaN             NaN
# 22968             NaN           NaN         NaN             NaN
# 24545             NaN           NaN         NaN             NaN
# 24978             NaN           NaN         NaN             NaN
# 28825             NaN           NaN         NaN             NaN
# 31283             NaN           NaN         NaN             NaN
# 33484             NaN           NaN         NaN             NaN
# 35010             NaN           NaN         NaN             NaN
# 35023             NaN           NaN         NaN             NaN
# 35436             NaN           NaN         NaN             NaN
# 38988             NaN           NaN         NaN             NaN
# 39139             NaN           NaN         NaN             NaN
# ...               ...           ...         ...             ...
# 218892            NaN           NaN         NaN             NaN
# 219909            1.0           0.0         0.0             0.0
# 220027            NaN           NaN         NaN             NaN
# 220635            NaN           NaN         NaN             NaN
# 223418            NaN           NaN         NaN             NaN
# 224463            NaN           NaN         NaN             NaN
# 225171            0.0           1.0         0.0             0.0
# 225712            NaN           NaN         NaN             NaN
# 226433            NaN           NaN         NaN             NaN
# 228764            NaN           NaN         NaN             NaN
# 228845            1.0           0.0         0.0             0.0
# 228938            2.0           0.0         0.0             0.0
# 229279            NaN           NaN         NaN             NaN
# 229328            1.0           0.0         0.0             0.0
# 229890            NaN           NaN         NaN             NaN
# 230147            0.0           1.0         0.0             0.0
# 231322            NaN           NaN         NaN             NaN
# 232219            NaN           NaN         NaN             NaN
# 234061            NaN           NaN         NaN             NaN
# 234309            NaN           NaN         NaN             NaN
# 235965            NaN           NaN         NaN             NaN
# 235992            NaN           NaN         NaN             NaN
# 236005            NaN           NaN         NaN             NaN
# 238028            NaN           NaN         NaN             NaN
# 238181            0.0           1.0         0.0             0.0
# 240404            NaN           NaN         NaN             NaN
# 243314            NaN           NaN         NaN             NaN
# 244030            0.0           1.0         0.0             0.0
# 245484            1.0           0.0         0.0             0.0
# 246473            NaN           NaN         NaN             NaN
#
#         weather_delay  nas_delay  security_delay  late_aircraft_delay  \
# 499               NaN        NaN             NaN                  NaN
# 513               NaN        NaN             NaN                  NaN
# 587               NaN        NaN             NaN                  NaN
# 4107              NaN        NaN             NaN                  NaN
# 4761              NaN        NaN             NaN                  NaN
# 4767              NaN        NaN             NaN                  NaN
# 10568             NaN        NaN             NaN                  NaN
# 10577             NaN        NaN             NaN                  NaN
# 11333             NaN        NaN             NaN                  NaN
# 11954             NaN        NaN             NaN                  NaN
# 11960             NaN        NaN             NaN                  NaN
# 12687             NaN        NaN             NaN                  NaN
# 13377             NaN        NaN             NaN                  NaN
# 15042             NaN        NaN             NaN                  NaN
# 15060             NaN        NaN             NaN                  NaN
# 15110             NaN        NaN             NaN                  NaN
# 17914             NaN        NaN             NaN                  NaN
# 20641             NaN        NaN             NaN                  NaN
# 21476             NaN        NaN             NaN                  NaN
# 22968             NaN        NaN             NaN                  NaN
# 24545             NaN        NaN             NaN                  NaN
# 24978             NaN        NaN             NaN                  NaN
# 28825             NaN        NaN             NaN                  NaN
# 31283             NaN        NaN             NaN                  NaN
# 33484             NaN        NaN             NaN                  NaN
# 35010             NaN        NaN             NaN                  NaN
# 35023             NaN        NaN             NaN                  NaN
# 35436             NaN        NaN             NaN                  NaN
# 38988             NaN        NaN             NaN                  NaN
# 39139             NaN        NaN             NaN                  NaN
# ...               ...        ...             ...                  ...
# 218892            NaN        NaN             NaN                  NaN
# 219909            0.0        0.0             0.0                  0.0
# 220027            NaN        NaN             NaN                  NaN
# 220635            NaN        NaN             NaN                  NaN
# 223418            NaN        NaN             NaN                  NaN
# 224463            NaN        NaN             NaN                  NaN
# 225171            0.0        0.0             0.0                  0.0
# 225712            NaN        NaN             NaN                  NaN
# 226433            NaN        NaN             NaN                  NaN
# 228764            NaN        NaN             NaN                  NaN
# 228845            0.0        0.0             0.0                  0.0
# 228938            0.0        0.0             0.0                  0.0
# 229279            NaN        NaN             NaN                  NaN
# 229328            0.0        0.0             0.0                  0.0
# 229890            NaN        NaN             NaN                  NaN
# 230147            0.0        0.0             0.0                  0.0
# 231322            NaN        NaN             NaN                  NaN
# 232219            NaN        NaN             NaN                  NaN
# 234061            NaN        NaN             NaN                  NaN
# 234309            NaN        NaN             NaN                  NaN
# 235965            NaN        NaN             NaN                  NaN
# 235992            NaN        NaN             NaN                  NaN
# 236005            NaN        NaN             NaN                  NaN
# 238028            NaN        NaN             NaN                  NaN
# 238181            0.0        0.0             0.0                  0.0
# 240404            NaN        NaN             NaN                  NaN
# 243314            NaN        NaN             NaN                  NaN
# 244030            0.0        0.0             0.0                  0.0
# 245484            0.0        0.0             0.0                  0.0
# 246473            NaN        NaN             NaN                  NaN
#
#         Unnamed: 21
# 499             NaN
# 513             NaN
# 587             NaN
# 4107            NaN
# 4761            NaN
# 4767            NaN
# 10568           NaN
# 10577           NaN
# 11333           NaN
# 11954           NaN
# 11960           NaN
# 12687           NaN
# 13377           NaN
# 15042           NaN
# 15060           NaN
# 15110           NaN
# 17914           NaN
# 20641           NaN
# 21476           NaN
# 22968           NaN
# 24545           NaN
# 24978           NaN
# 28825           NaN
# 31283           NaN
# 33484           NaN
# 35010           NaN
# 35023           NaN
# 35436           NaN
# 38988           NaN
# 39139           NaN
# ...             ...
# 218892          NaN
# 219909          NaN
# 220027          NaN
# 220635          NaN
# 223418          NaN
# 224463          NaN
# 225171          NaN
# 225712          NaN
# 226433          NaN
# 228764          NaN
# 228845          NaN
# 228938          NaN
# 229279          NaN
# 229328          NaN
# 229890          NaN
# 230147          NaN
# 231322          NaN
# 232219          NaN
# 234061          NaN
# 234309          NaN
# 235965          NaN
# 235992          NaN
# 236005          NaN
# 238028          NaN
# 238181          NaN
# 240404          NaN
# 243314          NaN
# 244030          NaN
# 245484          NaN
# 246473          NaN
#
# [401 rows x 22 columns]

# %% [markdown]
# ### Data Quality issues
#
# - Missing values in some columns
#
# - Date is not given as datetime object
#
# - some column names are misleading
#
# ### Data Tidiness issues
#
# - City, State and Airport are in the same column
#
# - "Unnamed:21" does not contain any data
#
# - Year and Month in different columns

# %% [markdown]
# ## Cleaning
#
# Define, code and test the cleaning tasks, which have been identified in the assessment section.

# %% [markdown]
# ### City, State and Airport are in the same column
#
# #### Define
# Split column airport_name and save each information in two different columns.
#
# #### Code

# %%
# Split string in airport_name
airport_cols = df_flight["airport_name"].str.split(": ",expand=True)
# Create new columns in dataset
df_flight["airport_name"] = airport_cols[1]
df_flight["city"] = airport_cols[0]

# %% [markdown]
# #### Test

# %%
df_flight.sample(10)
# Out:
#         year   month carrier                 carrier_name airport  \
# 127161  2010       8      B6              JetBlue Airways     BWI
# 139940  2011       5      EV  Atlantic Southeast Airlines     SAV
# 793     2003       6      NW      Northwest Airlines Inc.     PWM
# 158116  2012       7      US              US Airways Inc.     SJC
# 233537  2018       1      9E            Endeavor Air Inc.     FLL
# 233066  2018       1      OO        SkyWest Airlines Inc.     SBA
# 54263   2006       8      WN       Southwest Airlines Co.     ABQ
# 147337  2011      11      AA       American Airlines Inc.     MCI
# 154626  2012       4      WN       Southwest Airlines Co.     PIT
# 17546   2004       7      EV  Atlantic Southeast Airlines     OKC
#
#                                              airport_name  arr_flights  \
# 127161  Baltimore/Washington International Thurgood Ma...        151.0
# 139940                 Savannah/Hilton Head International         95.0
# 793                        Portland International Jetport         60.0
# 158116            Norman Y. Mineta San Jose International        154.0
# 233537            Fort Lauderdale-Hollywood International         29.0
# 233066                            Santa Barbara Municipal        349.0
# 54263                   Albuquerque International Sunport       1723.0
# 147337                          Kansas City International        308.0
# 154626                           Pittsburgh International        533.0
# 17546                                   Will Rogers World         93.0
#
#         arr_del15  carrier_ct   weather_ct         ...           \
# 127161       35.0       14.59         0.00         ...
# 139940       28.0        9.85         0.00         ...
# 793           8.0        2.59         0.00         ...
# 158116        9.0        4.60         0.00         ...
# 233537        7.0        2.08         0.00         ...
# 233066       67.0       18.71         0.00         ...
# 54263       320.0       82.80         4.17         ...
# 147337       60.0       26.38         1.89         ...
# 154626       77.0       37.23         1.41         ...
# 17546        20.0        8.11         2.54         ...
#
#         arr_cancelled  arr_diverted   arr_delay   carrier_delay  \
# 127161            0.0           1.0      2780.0          1288.0
# 139940            5.0           0.0      1824.0           644.0
# 793               0.0           0.0       196.0            67.0
# 158116            0.0           0.0       556.0           310.0
# 233537            0.0           0.0       496.0           358.0
# 233066            5.0           3.0      5193.0          1987.0
# 54263             2.0           1.0     14565.0          3458.0
# 147337            0.0           0.0      3075.0          1324.0
# 154626            0.0           0.0      3217.0          1676.0
# 17546             1.0           0.0       989.0           358.0
#
#         weather_delay  nas_delay  security_delay  late_aircraft_delay  \
# 127161            0.0      553.0             0.0                939.0
# 139940            0.0      234.0             0.0                946.0
# 793               0.0      129.0             0.0                  0.0
# 158116            0.0      102.0             0.0                144.0
# 233537            0.0       98.0             0.0                 40.0
# 233066            0.0      490.0             0.0               2716.0
# 54263           161.0     1495.0           303.0               9148.0
# 147337          104.0      449.0             0.0               1198.0
# 154626           82.0      166.0             0.0               1293.0
# 17546           165.0      217.0             0.0                249.0
#
#         Unnamed: 21                 city
# 127161          NaN        Baltimore, MD
# 139940          NaN         Savannah, GA
# 793             NaN         Portland, ME
# 158116          NaN         San Jose, CA
# 233537          NaN  Fort Lauderdale, FL
# 233066          NaN    Santa Barbara, CA
# 54263           NaN      Albuquerque, NM
# 147337          NaN      Kansas City, MO
# 154626          NaN       Pittsburgh, PA
# 17546           NaN    Oklahoma City, OK
#
# [10 rows x 23 columns]

# %% [markdown]
# ### "Unnamed:21" does not contain any data
#
# #### Define
# The column "Unnamed: 21" has to be dropped.
#
# #### Code

# %%
# Drop column "Unnamed: 21"
df_flight.drop(["Unnamed: 21"], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
# View dataset summary
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247718 entries, 0 to 247717
# Data columns (total 22 columns):
# year                   247718 non-null int64
#  month                 247718 non-null int64
# carrier                247718 non-null object
# carrier_name           247718 non-null object
# airport                247718 non-null object
# airport_name           247718 non-null object
# arr_flights            247368 non-null float64
# arr_del15              247317 non-null float64
# carrier_ct             247368 non-null float64
#  weather_ct            247368 non-null float64
# nas_ct                 247368 non-null float64
# security_ct            247368 non-null float64
# late_aircraft_ct       247368 non-null float64
# arr_cancelled          247368 non-null float64
# arr_diverted           247368 non-null float64
#  arr_delay             247368 non-null float64
#  carrier_delay         247368 non-null float64
# weather_delay          247368 non-null float64
# nas_delay              247368 non-null float64
# security_delay         247368 non-null float64
# late_aircraft_delay    247368 non-null float64
# city                   247718 non-null object
# dtypes: float64(15), int64(2), object(5)
# memory usage: 41.6+ MB

# %% [markdown]
# ### Year and Month in different columns
#
# #### Define
# Year and Month belong to one variable (date) but are separated in two columns, which is in indicator for 'messy data'.
# Both variables have to be concatenated as a string in one column. Since no week or day information are given in the dataset, we assume the first of each month to create a complete date.
# Columns Year and Month can be dropped.
#
# #### Code

# %%
# put Year and Month together in one column as a string
df_flight["date"] = df_flight["year"].map(str) + "-" + df_flight[" month"].map("{:02}".format) + "-01"

# Drop Year and Month
df_flight.drop(["year"," month"], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
# View Sample of rows
df_flight.sample(10)
# Out:
#        carrier                  carrier_name airport  \
# 73197       UA         United Air Lines Inc.     PVD
# 214769      OO         SkyWest Airlines Inc.     CAE
# 98144       FL   AirTran Airways Corporation     ATL
# 36086       MQ  American Eagle Airlines Inc.     OKC
# 204138      MQ                     Envoy Air     JFK
# 1077        UA         United Air Lines Inc.     GRR
# 191669      OO         SkyWest Airlines Inc.     ELP
# 58999       YV            Mesa Airlines Inc.     FLG
# 111997      UA         United Air Lines Inc.     PDX
# 156433      F9        Frontier Airlines Inc.     HOU
#
#                                     airport_name  arr_flights  arr_del15  \
# 73197               Theodore Francis Green State        155.0       65.0
# 214769                     Columbia Metropolitan          3.0        1.0
# 98144   Hartsfield-Jackson Atlanta International       6537.0     2135.0
# 36086                          Will Rogers World        271.0       55.0
# 204138             John F. Kennedy International        165.0       39.0
# 1077                Gerald R. Ford International        109.0       30.0
# 191669                     El Paso International        240.0       25.0
# 58999                          Flagstaff Pulliam        146.0       18.0
# 111997                    Portland International        368.0       33.0
# 156433                           William P Hobby          2.0        2.0
#
#         carrier_ct   weather_ct  nas_ct  security_ct     ...      \
# 73197        17.26         2.78   11.18          0.0     ...
# 214769        1.00         0.00    0.00          0.0     ...
# 98144       198.63        17.97  891.38          0.0     ...
# 36086        21.72         5.33   11.86          0.0     ...
# 204138       14.67         0.07   13.26          1.0     ...
# 1077          5.31         0.11   14.20          0.0     ...
# 191669       10.73         0.70    7.27          0.0     ...
# 58999        18.00         0.00    0.00          0.0     ...
# 111997        7.60         0.10    4.14          0.0     ...
# 156433        1.01         0.00    0.06          0.0     ...
#
#         arr_cancelled  arr_diverted   arr_delay   carrier_delay  \
# 73197             3.0           0.0      4532.0          1271.0
# 214769            0.0           0.0       135.0           135.0
# 98144            97.0           6.0    106590.0          9691.0
# 36086             2.0           0.0      2470.0           990.0
# 204138            7.0           0.0      2518.0          1188.0
# 1077              0.0           0.0      1290.0           274.0
# 191669            1.0           0.0      1132.0           413.0
# 58999             0.0           0.0      1082.0          1082.0
# 111997            1.0           0.0      2318.0           752.0
# 156433            0.0           0.0       274.0            71.0
#
#         weather_delay  nas_delay  security_delay  late_aircraft_delay  \
# 73197           177.0      452.0             0.0               2632.0
# 214769            0.0        0.0             0.0                  0.0
# 98144          1270.0    37034.0             0.0              58595.0
# 36086           263.0      312.0             0.0                905.0
# 204138            3.0      692.0            56.0                579.0
# 1077             10.0      421.0             0.0                585.0
# 191669           45.0      179.0             0.0                495.0
# 58999             0.0        0.0             0.0                  0.0
# 111997            9.0      172.0             0.0               1385.0
# 156433            0.0       12.0             0.0                191.0
#
#                      city        date
# 73197      Providence, RI  2007-08-01
# 214769       Columbia, SC  2016-07-01
# 98144         Atlanta, GA  2008-12-01
# 36086   Oklahoma City, OK  2005-08-01
# 204138       New York, NY  2015-09-01
# 1077     Grand Rapids, MI  2003-06-01
# 191669        El Paso, TX  2014-10-01
# 58999       Flagstaff, AZ  2006-11-01
# 111997       Portland, OR  2009-09-01
# 156433        Houston, TX  2012-06-01
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Date is not given as datetime object
#
# #### Define
# The created date column is given as string and has to be converted into datetime object.
#
# #### Code

# %%
# Format date to datetime object
df_flight["date"] = pd.to_datetime(df_flight["date"], format='%Y-%m-%d')

# %% [markdown]
# #### Test

# %%
# Check info()-function for datatype of column date
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247718 entries, 0 to 247717
# Data columns (total 21 columns):
# carrier                247718 non-null object
# carrier_name           247718 non-null object
# airport                247718 non-null object
# airport_name           247718 non-null object
# arr_flights            247368 non-null float64
# arr_del15              247317 non-null float64
# carrier_ct             247368 non-null float64
#  weather_ct            247368 non-null float64
# nas_ct                 247368 non-null float64
# security_ct            247368 non-null float64
# late_aircraft_ct       247368 non-null float64
# arr_cancelled          247368 non-null float64
# arr_diverted           247368 non-null float64
#  arr_delay             247368 non-null float64
#  carrier_delay         247368 non-null float64
# weather_delay          247368 non-null float64
# nas_delay              247368 non-null float64
# security_delay         247368 non-null float64
# late_aircraft_delay    247368 non-null float64
# city                   247718 non-null object
# date                   247718 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(15), object(5)
# memory usage: 39.7+ MB

# %% [markdown]
# ### Missing values in some columns
#
# #### Define
# Some delay information are missing in the dataset. Corresponding rows are useless for the analysis and visualization of flight delays or cancellations. Thus, these observations can be dropped.
#
# #### Code

# %%
# Drop rows with NaN in the "arr_flight" column
df_flight.dropna(inplace=True)

# %% [markdown]
# #### Test

# %%
# Check the info()-function - all columns have to be exactly the same amount of non-null values
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247317 entries, 0 to 247717
# Data columns (total 21 columns):
# carrier                247317 non-null object
# carrier_name           247317 non-null object
# airport                247317 non-null object
# airport_name           247317 non-null object
# arr_flights            247317 non-null float64
# arr_del15              247317 non-null float64
# carrier_ct             247317 non-null float64
#  weather_ct            247317 non-null float64
# nas_ct                 247317 non-null float64
# security_ct            247317 non-null float64
# late_aircraft_ct       247317 non-null float64
# arr_cancelled          247317 non-null float64
# arr_diverted           247317 non-null float64
#  arr_delay             247317 non-null float64
#  carrier_delay         247317 non-null float64
# weather_delay          247317 non-null float64
# nas_delay              247317 non-null float64
# security_delay         247317 non-null float64
# late_aircraft_delay    247317 non-null float64
# city                   247317 non-null object
# date                   247317 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(15), object(5)
# memory usage: 41.5+ MB

# %% [markdown]
# ### Some column names are misleading
#
# #### Define
# Rename column names using a dictionary.
#
# #### Code

# %%
# Define a dictionary and rename columns
new_cols = {"carrier":"Carrier",
            "carrier_name": "Carrier_Name",
            "airport":"Airport",
            "airport_name":"Airport_Name",
            "arr_flights":"Flights_count",
            "arr_del15":"Delays_count",
            "carrier_ct":"Carrier_Delays_count",
            " weather_ct":"Weather_Delays_count",
            "nas_ct":"NAS_Delays_count",
            "security_ct":"Security_Delays_count",
            "late_aircraft_ct":"Late_Aircraft_Delays_count",
            "arr_cancelled":"Cancellations_count",
            "arr_diverted":"Diversions_count",
            " arr_delay":"Delay_minutes",
            " carrier_delay":"Carrier_Delay_minutes",
            "weather_delay":"Weather_Delay_minutes",
            "nas_delay":"NAS_Delay_minutes",
            "security_delay":"Security_Delay_minutes",
            "late_aircraft_delay":"Late_Aircraft_Delay_minutes",
            "city":"City",
            "date":"Date"}
df_flight.rename(index=str, columns=new_cols,inplace=True)

# %% [markdown]
# #### Test

# %%
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 247317 entries, 0 to 247717
# Data columns (total 21 columns):
# Carrier                        247317 non-null object
# Carrier_Name                   247317 non-null object
# Airport                        247317 non-null object
# Airport_Name                   247317 non-null object
# Flights_count                  247317 non-null float64
# Delays_count                   247317 non-null float64
# Carrier_Delays_count           247317 non-null float64
# Weather_Delays_count           247317 non-null float64
# NAS_Delays_count               247317 non-null float64
# Security_Delays_count          247317 non-null float64
# Late_Aircraft_Delays_count     247317 non-null float64
# Cancellations_count            247317 non-null float64
# Diversions_count               247317 non-null float64
# Delay_minutes                  247317 non-null float64
# Carrier_Delay_minutes          247317 non-null float64
# Weather_Delay_minutes          247317 non-null float64
# NAS_Delay_minutes              247317 non-null float64
# Security_Delay_minutes         247317 non-null float64
# Late_Aircraft_Delay_minutes    247317 non-null float64
# City                           247317 non-null object
# Date                           247317 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(15), object(5)
# memory usage: 41.5+ MB

# %% [markdown]
# ## Storage
#
# We store the dataset as a new Excel-file.

# %%
# Save to Excel-file
df_flight.to_excel('Airline On-Time Statistics and Delay Causes.xlsx',index=False)
